# %%
import pandas as pd
import datetime as dt
import json
import os
from icalendar import Calendar, Event
import numpy as np
import json

def stringtodate(date, time, timezone):
    if(np.isnan(date) or np.isnan(time) or np.isnan(timezone)):
        return;
    string = date+' '+time+timezone[4:10].replace(':','')
    return dt.datetime.strptime(string,"%d/%m/%Y %H:%M:%S%z")

def formatstring(date, time, timezone):
        if(np.isnan(date) or np.isnan(time) or np.isnan(timezone)):
        return '';
    date = stringtodate(date,time,timezone)
    return dt.datetime.strftime(date,"%Y-%m-%dT%H:%M:%S"+timezone[4:10])

# %%
data = pd.read_csv('../data.csv')

# %% [markdown]
# # Parse the posts

# %%
base_string = \
'''+++
  host= "{host}"
  date = "{start_time}"
  expiryDate = "{end_time}"
  title = "{title}"
  speaker = "{speaker}"
  speaker_institution = "{speaker_inst}"
  talk_site = "{talk_site}"
  categories = [{categories}]

  publishDate = "2000-02-07T16:00:00-07:00"
+++

{abstract}'''

# %%
parser = {
    'host': lambda x:x['Host'],
    'title': lambda x: x['Title'],
    'start_time' : lambda x : formatstring(x['Date'],x['Start_Time'], x['Timezone']),
    'end_time' : lambda x : formatstring(x['Date'],x['End_Time'], x['Timezone']),
    'start_time_as_date': lambda x: stringtodate(x['Date'],x['Start_Time'], x['Timezone']),
    'end_time_as_date': lambda x: stringtodate(x['Date'],x['End_Time'], x['Timezone']),
    'speaker' : lambda x: x['Speaker'],
    'speaker_inst': lambda x: x['Speaker_inst'],
    'timezone': lambda x: x['Timezone'][4:10].replace(':',''),
    'talk_site': lambda x: x['Site'],
    'categories': lambda x : '' if (not isinstance(x['arXiv'],str) or str(x['arXiv']).lstrip().rstrip() =='') \
                                else '"'+'","'.join(x['arXiv'].upper().replace(' ','').replace('MATH.','').split(','))+'"',
    'abstract': lambda x: x['Abstract'],
    'name': lambda x: 'talk/'+(x['Host']+'_'+x['Speaker'].replace(' ','_')+'_'+x['Date']).replace('/','')+'.md'
}

# %%
for row in data.iterrows():
    mydict = { prop:func(row[1]) for prop, func in parser.items()}
    break;
    with open(mydict['name'], 'w') as f:
        f.write(base_string.format(**mydict))

# %%
mydict
# Out:
# {'host': 'UCLA',
#  'title': 'A p-adic monodromy theorem for de Rham local systems',
#  'start_time': '2020-04-06T16:00:00-07:00',
#  'end_time': '2020-04-06T16:50:00-07:00',
#  'start_time_as_date': datetime.datetime(2020, 4, 6, 16, 0, tzinfo=datetime.timezone(datetime.timedelta(-1, 61200))),
#  'end_time_as_date': datetime.datetime(2020, 4, 6, 16, 50, tzinfo=datetime.timezone(datetime.timedelta(-1, 61200))),
#  'speaker': 'Koji Shimizu',
#  'speaker_inst': 'IAS',
#  'timezone': '-0700',
#  'talk_site': 'https://secure.math.ucla.edu/seminars/display.php?&id=833983',
#  'categories': '"AG","NT"',
#  'abstract': 'Every smooth proper algebraic variety over a p-adic field is expected to have semistable model after passing to a finite extension. This conjecture is open in general, but its analogue for p-adic Galois representations, the p-adic monodromy theorem, is known. In this talk, we will explain a generalization of this theorem to etale local systems on a smooth rigid analytic variety.',
#  'name': 'talk/UCLA_Koji_Shimizu_06042020.md'}

# %%
mydict['categories']
# Out:
# '"AG","NT"'

# %%
cal_parser = {
    'uid': lambda x:  x['name'][5:-3],
    'name': lambda x:  x['title'] + ' - ' + x['speaker'],
    'description': lambda x:  ('Host: {host} \n Speaker: {speaker} ({speaker_inst}) \n\n --- \n{abstract}'+\
                               '\n\n---\n Event generated by jaume.dedios.cat/math-seminars').format(**x) ,
    'dtstart': lambda x:  x['start_time_as_date'],
    'dtend': lambda x:  x['end_time_as_date'],
    'categories': lambda x:  ['math.'+y[1:-1] for y in '"AP","DG"'.split(',')],
    'location': lambda x: x['host'],
    'url': lambda x: x['talk_site'],
    'summary': lambda x: '{title} -- {speaker} ({speaker_inst})'.format(**x),
}

# %%
data_recurrent = pd.read_csv('Data_Recurrent.csv')

# %%
day_map = {'Monday':0, 
           'Tuesday':1,
           'Wednesday':2, 
           'Thursday':3, 
           'Friday':4, 
           'Saturday':5, 
           'Sunday':6,
            np.nan: -1}

mock_date_map = \
          {'Monday':'2020-04-06T', 
           'Tuesday':'2020-04-07T', 
           'Wednesday':'2020-04-08T',  
           'Thursday':'2020-04-09T',  
           'Friday':'2020-04-10T', 
           'Saturday':'2020-04-11T', 
           'Sunday':'2020-04-12T',
            np.nan: ''}

# %%
def mock_time(day, time, timezone, mock_date_map=mock_date_map):
    if( not isinstance(time,str) or not isinstance(timezone,str)):
        return '';
    return mock_date_map[day]+time+timezone[4:]
def checkstring(st):
    return st if isinstance(st, str) else ''

# %%
recurrent_parser = {
    'day_index': lambda x: day_map[x['Day']],
    'weekday': lambda x: x['Day'],
    'name': lambda x: x['Name'],
    'start_time': lambda x: mock_time(x['Day'],x['Time_start'], x['Timezone']),
    'timestamp': lambda x: int(dt.datetime.strptime(mock_time(x['Day'],x['Time_start'], x['Timezone'])[:-3]+'00',
                                                    "%Y-%m-%dT%H:%M:%S%z").timestamp()),
    'end_time': lambda x: mock_time(x['Day'],x['Time_end'], x['Timezone']),
    'start_time_2': lambda x: mock_time(x['Day_2'],x['Time_start_2'], x['Timezone']),
    'end_time_2': lambda x: mock_time(x['Day_2'],x['Time_end_2'], x['Timezone']),
    'Time_comments': lambda x: checkstring(x['Time_comments']),
    'URL' : lambda x : x['Link'],
    'host_inst' : lambda x : checkstring(x['Institution']),
    'categories': lambda x : [] if (not isinstance(x['Arxiv_Cat'],str) or str(x['Arxiv_Cat']).lstrip().rstrip() =='') \
                                 else (x['Arxiv_Cat'].upper().replace(' ','').replace('MATH.','').split(',')),
}

# %%
recurrent_events = [{prop: func(row) for prop,func in recurrent_parser.items()}
                        for _,row in data_recurrent.iterrows() 
                            if row['Regular']=='YES']

# %%
for x in recurrent_events:
    print(x['timestamp'])
# Out:
# 1583510400
# 1583499600
# 1583508600
# 1583528400
# 1583503200
# 1583505000
# 1583503200
# 1583523000
# 1583503200
# 1583499600
# 1583506800
# 1583526900
# 1583536200
# 1583506800
# 1583499600
# 1583521200
# 1583503800
# 1583514000
# 1583521800
# 1583521200
# 1583517600
# 1583526600
# 1583526600
# 1583510400
# 1583503200
# 1583496000
# 1583510400
# 1583523000
# 1583514000
# 1583510400
# 1583514000
# 1583526600
# 1583521200
# 1583524800
# 1583523000
# 1583506800
# 1583494200
# 1583485200
# 1583517600
# 1583503200
# 1583517600
# 1583505000
# 1583517600
# 1583499600
# 1583499600
# 1583503200
# 1583499600
# 1583509500
# 1583519400
# 1583521200
# 1583524800
# 1583503200
# 1583517600
# 1583510400

# %%
with open('recurrent.json', 'w') as f:
    json.dump(recurrent_events, fp=f)

# %%
data_recurrent
# Out:
#                                                  Name  \
# 0                    MIT (Applied) Categories Seminar
# 1                       One World Probability Seminar
# 2    Electronic Computational Homotopy Theory Seminar
# 3   Seminario "flotante" de Lógica Matemática de B...
# 4                               One World PDE Seminar
# 5                   Séminaire de Groupes et Géométrie
# 6        Online Asymptotic Geometric Analysis Seminar
# 7                              Banach spaces webinars
# 8       Number Theory / Representation Theory Seminar
# 9   Virtual seminar on algebraic matroids and rigi...
# 10  Oxford Discrete Mathematics and Probability Se...
# 11                   Nonlinear Algebra Seminar Online
# 12                          UMN Combinatorics Seminar
# 13                 Combinatorics and Geometry Seminar
# 14                           Complex Geometry Seminar
# 15          TCS+ Theoretical Computer Science Seminar
# 16                The Applied Algebra Seminar at York
# 17  GAPT (Geometry, Algebra, Mathematical Physics ...
# 18           Graduate Online Combinatorics Colloquium
# 19                   Virtual Combinatorics Colloquium
# 20                  UC Berkeley Combinatorics Seminar
# 21                     Women in Combinatorics Seminar
# 22                                     TGGT: Topology
# 23                       TGGT: Geometric group theory
# 24                               MIT Topology Seminar
# 25  HOTTEST: Homotopy Type Theory Electronic Semin...
# 26  Applied Algebraic Topology Research Network Se...
# 27           Online Algebraic Topology Seminar (OATS)
# 28                                   Seminar GEOTOP-A
# 29                         [K-OS] Knot Online Seminar
# ..                                                ...
# 31                           CUNY Probability Seminar
# 32                       Stanford Probability Seminar
# 33                    ACT@UCR Applied Category Theory
# 34        Electronic Seminar on Mathematics Education
# 35                                            VaNTAGe
# 36                             MIT Lie Groups Seminar
# 37                               Gauge Theory Virtual
# 38                           MIT PDE/Analysis Seminar
# 39                             NIMBioS Webinar Series
# 40                           Probability and the city
# 41  Horowitz Seminar on Probability, Ergodic Theor...
# 42                       Helsinki Logic Group Seminar
# 43  Southern Illinois University Online Logic Seminar
# 44               IMJ-PRG Séminaire Général de Logique
# 45                Columbia Geometric Topology Seminar
# 46                            NY Group Theory Seminar
# 47                         Edimburgh Geometry Seminar
# 48                Stanford Algebraic Geometry Seminar
# 49  EPC Extremal and Probabilistic Combinatorics W...
# 50         International Seminar on Automorphic Forms
# 51                                 Waves in one world
# 52                      One world game theory seminar
# 53  One world mathematical methods for arbitrary d...
# 54                     New York Combinatorics Seminar
# 55  One world MINDS: Mathematics of Information Da...
# 56  Western Hemisphere Colloquium on Geometry and ...
# 57           Online working seminar in ergodic theory
# 58                               Math and Data (MAD+)
# 59                 Virtual Lecture Series in Dynamics
# 60      Algebraic topology from a geometric viewpoint
#
#                           Institution  \
# 0                                 MIT
# 1                   One World Seminar
# 2                    Wayne University
# 3                  Bogotá Logic Group
# 4                   One World Seminar
# 5                University of Geneva
# 6                        Georgia Tech
# 7           University of North Texas
# 8   University of Wisconsin - Madison
# 9                                 MIT
# 10                  Oxford University
# 11                        MPI Leipzig
# 12            University of Minnesota
# 13           University of Washington
# 14                           Chalmers
# 15                               TCS+
# 16                York University, Ca
# 17                            Cardiff
# 18                                NaN
# 19    Northeast Combinatorics Network
# 20                        UC Berkeley
# 21                             WinCom
# 22              Ohio State University
# 23              Ohio State University
# 24                                MIT
# 25      University of Western Onterio
# 26            University of Minnesota
# 27                                NaN
# 28                           GEOTOP-A
# 29            Geneva University, CNRS
# ..                                ...
# 31                               CUNY
# 32                           Stanford
# 33                       UC RIverside
# 34                                MIT
# 35                                NaN
# 36                                MIT
# 37                                NaN
# 38                                MIT
# 39                            MIMBioS
# 40                       NYU/Columbia
# 41                Tel Aviv University
# 42             University of Helsinki
# 43       Southern Illinois University
# 44                           IMJ-PRG
# 45                           Columbia
# 46        NY Group Theory Cooperative
# 47          Edinburgh Hodge Institute
# 48                           Stanford
# 49                                NaN
# 50           TU Darmstadt, ETH Zurich
# 51                  One World Seminar
# 52                  One World Seminar
# 53                  One World Seminar
# 54                               CUNY
# 55                  One World Seminar
# 56                                NaN
# 57                 University of Utah
# 58                      NYU CDS, ETHZ
# 59             Univeristy of Maryland
# 60               University of Oregon
#
#                                                  Link  \
# 0                 http://brendanfong.com/seminar.html
# 1   https://www.wim.uni-mannheim.de/doering/one-wo...
# 2                   https://s.wayne.edu/isaksen/echt/
# 3   https://sites.google.com/view/bogotalogica/cou...
# 4             https://people.bath.ac.uk/mw2319/owpde/
# 5   https://www.unige.ch/math/fr/annonces/groupes-...
# 6   http://people.math.gatech.edu/~glivshyts6/AGAo...
# 7            http://www.math.unt.edu/~bunyamin/banach
# 8        https://www.math.wisc.edu/wiki/index.php/NTS
# 9   https://dibernstein.github.io/VirtualSeminar.html
# 10         http://people.maths.ox.ac.uk/scott/dmp.htm
# 11    https://www.mis.mpg.de/nlalg/seminars/naso.html
# 12  http://www-users.math.umn.edu/~cfraser/seminar...
# 13  https://math.washington.edu/events/series/comb...
# 14            https://sites.google.com/view/cgseminar
# 15             https://sites.google.com/site/plustcs/
# 16   http://garsia.math.yorku.ca/seminar/algebra.html
# 17       https://upennig.weebly.com/gapt-seminar.html
# 18   https://sites.google.com/view/gocc-combinatorics
# 19  https://sites.google.com/view/northeastcombina...
# 20  https://math.berkeley.edu/~corteel/combinatorics/
# 21  https://sites.google.com/view/womenincombinato...
# 22      https://sites.google.com/view/topoandggt/home
# 23      https://sites.google.com/view/topoandggt/home
# 24           https://math.mit.edu/topology/index.html
# 25  https://www.uwo.ca/math/faculty/kapulkin/semin...
# 26              https://topology.ima.umn.edu/seminars
# 27  https://sites.google.com/view/nialltaggartmath...
# 28                       http://seminargeotop-a.com/#
# 29        https://lrobert.perso.math.cnrs.fr/kos.html
# ..                                                ...
# 31           https://probability.commons.gc.cuny.edu/
# 32  https://statistics.stanford.edu/events/probabi...
# 33  https://sites.google.com/ucr.edu/actucr/home?a...
# 34                https://math.mit.edu/seminars/esme/
# 35       https://sites.google.com/view/vantageseminar
# 36                   http://www-math.mit.edu/~dav/LG/
# 37  https://gaugetheoryvirtual.wordpress.com/semin...
# 38        https://math.mit.edu/seminars/pde-analysis/
# 39                    http://www.nimbios.org/webinars
# 40  https://math.nyu.edu/seminars/probability/patc...
# 41  http://www.math.tau.ac.il/~peledron/Horowitz_s...
# 42     https://wiki.helsinki.fi/display/Logic/Seminar
# 43  http://lagrange.math.siu.edu/calvert/OnlineLog...
# 44  https://www.imj-prg.fr/gestion/evenement/affEv...
# 45          https://www.math.columbia.edu/~gtseminar/
# 46  https://sites.google.com/site/nygrouptheory/ne...
# 47             https://hodge.maths.ed.ac.uk/tiki/EDGE
# 48                            https://agstanford.com/
# 49          https://sites.google.com/view/epcwebinar/
# 50  https://www2.mathematik.tu-darmstadt.de/~inter...
# 51        https://sites.google.com/view/waves-ow/home
# 52  https://gametheorynetwork.com/one-world-game-t...
# 53           http://www.nonlocal-methods.eu/oneworld/
# 54  http://userhome.brooklyn.cuny.edu/skingan/Comb...
# 55   https://sites.google.com/view/minds-seminar/home
# 56               http://web.math.ucsb.edu/~drm/WHCGP/
# 57    http://www.math.utah.edu/~chaika/workingseminar
# 58                    http://mad.cds.nyu.edu/madplus/
# 59  https://www-math.umd.edu/dynamics-conference.html
# 60  https://pages.uoregon.edu/dps/GeometricAlgebra...
#
#                                       Arxiv_Cat Regular    Timezone  \
# 0                                       math.CT     YES  UTC -04:00
# 1                                       math.PR     YES  UTC +02:00
# 2                                       math.LO     YES  UTC -04:00
# 3                                       math.LO     YES  UTC -05:00
# 4                                       math.AP     YES  UTC +01:00
# 5                                       math.GR      NO  UTC +02:00
# 6                                       math.AP     YES  UTC -04:00
# 7                                       math.FA     YES  UTC -05:00
# 8                              math.RT, math.NT     YES  UTC -05:00
# 9                     math.CO, math.AG, math.MG     YES  UTC -04:00
# 10                             math.PR, math.CO     YES  UTC +01:00
# 11                             math.CO, math.AG     YES  UTC +02:00
# 12                                      math.CO     YES  UTC -05:00
# 13                             math.CO, math.MG     YES  UTC -07:00
# 14                             math.CV, math.AG     YES  UTC -05:00
# 15                                          NaN     YES  UTC +00:00
# 16                             math.AG, math.CO     YES  UTC -04:00
# 17  math.GT, math.AT, math.DG, math.CA, math.MP     YES  UTC +01:00
# 18                                      math.CO     YES  UTC -04:00
# 19                                      math.CO      NO         NaN
# 20                                      math.CO     YES  UTC -07:00
# 21                                      math.CO    YES   UTC -04:00
# 22                    math.GT, math.AT, math.GN     YES  UTC -04:00
# 23                             math.GR, math.MG     YES  UTC -04:00
# 24                    math.GN, math.AT, math.GT     YES  UTC -04:00
# 25                                      math.LO     YES  UTC -04:00
# 26                                      math.AT     YES  UTC -04:00
# 27                                      math.AT     YES  UTC +02:00
# 28                                      math.GT      NO         NaN
# 29                                      math.GT     YES  UTC +02:00
# ..                                          ...     ...         ...
# 31                                      math.PR     YES  UTC -04:00
# 32                                      math.PR    YES   UTC -07:00
# 33                                      math.CT     YES  UTC -07:00
# 34                              math.GE,math.HO     YES  UTC -04:00
# 35                             math.NT, math.AG     YES  UTC -04:00
# 36                             math.GR, math.DG     YES  UTC -04:00
# 37                                      math.MP     YES  UTC -07:00
# 38                             math.AP, math.CA     YES  UTC -04:00
# 39                                          NaN     YES  UTC -04:00
# 40                                      math.PR     YES  UTC -04:00
# 41                             math.PR, math.DS     YES  UTC +03:00
# 42                                      math.LO     YES  UTC +03:00
# 43                                      math.LO     YES  UTC -05:00
# 44                                      math.LO     YES  UTC +02:00
# 45                                      math.GT     YES  UTC -04:00
# 46                                      math.GR      NO         NaN
# 47                              math.DG,math.MG     YES  UTC +01:00
# 48                                      math.AG     YES  UTC -07:00
# 49                             math.CO, math.PR     YES  UTC +00:00
# 50                             math.NT, math.AG     YES  UTC +02:00
# 51                                      math.AP     YES  UTC +01:00
# 52                                          NaN     YES  UTC +02:00
# 53                                          NaN      NO         NaN
# 54                                      math.CO     YES  UTC -04:00
# 55                                      Math.IT     YES  UTC -04:00
# 56                             Math.MP, math.DG     YES  UTC -07:00
# 57                             Math.PR, Math.DS     YES  UTC -06:00
# 58                                          NaN     YES  UTC +02:00
# 59                                      Math.DS     YES  UTC -04:00
# 60                                      Math.AT     YES  UTC -07:00
#
#           Day Time_start  Time_end     Day_2 Time_start_2 Time_end_2  \
# 0    Thursday   12:00:00  13:00:00       NaN          NaN        NaN
# 1    Thursday   15:00:00  17:00:00       NaN          NaN        NaN
# 2    Thursday   11:30:00  12:30:00       NaN          NaN        NaN
# 3   Wednesday   16:00:00  17:00:00       NaN          NaN        NaN
# 4     Tuesday   15:00:00  17:00:00       NaN          NaN        NaN
# 5         NaN        NaN       NaN       NaN          NaN        NaN
# 6     Tuesday   10:30:00  11:30:00  Saturday     11:30:00   12:30:00
# 7      Friday    9:00:00  10:00:00       NaN          NaN        NaN
# 8    Thursday   14:30:00  15:30:00       NaN          NaN        NaN
# 9    Thursday   10:00:00  11:00:00       NaN          NaN        NaN
# 10    Tuesday   14:00:00  16:30:00       NaN          NaN        NaN
# 11    Tuesday   17:00:00  19:00:00  Thursday     17:00:00   19:00:00
# 12     Friday   15:35:00  16:25:00       NaN          NaN        NaN
# 13  Wednesday   16:10:00  17:10:00       NaN          NaN        NaN
# 14     Monday   10:00:00  11:00:00       NaN          NaN        NaN
# 15  Wednesday   13:00:00  14:00:00       NaN          NaN        NaN
# 16     Monday   15:00:00  16:00:00       NaN          NaN        NaN
# 17   Thursday   15:10:00  16:00:00       NaN          NaN        NaN
# 18  Wednesday   13:00:00  14:00:00       NaN          NaN        NaN
# 19        NaN        NaN       NaN       NaN          NaN        NaN
# 20     Monday   12:10:00  13:00:00       NaN          NaN        NaN
# 21   Thursday   15:00:00  16:00:00       NaN          NaN        NaN
# 22    Tuesday   15:00:00  16:00:00       NaN          NaN        NaN
# 23   Thursday   14:00:00  15:00:00       NaN          NaN        NaN
# 24     Monday   16:30:00  17:30:00       NaN          NaN        NaN
# 25   Thursday   16:30:00  18:00:00       NaN          NaN        NaN
# 26  Wednesday   12:00:00  13:00:00       NaN          NaN        NaN
# 27     Monday   16:00:00  17:00:00       NaN          NaN        NaN
# 28        NaN        NaN       NaN       NaN          NaN        NaN
# 29   Thursday   14:00:00  15:00:00       NaN          NaN        NaN
# ..        ...        ...       ...       ...          ...        ...
# 31    Tuesday   15:30:00  16:30:00       NaN          NaN        NaN
# 32     Monday   16:00:00  17:00:00       NaN          NaN        NaN
# 33  Wednesday   10:00:00  11:00:00       NaN          NaN        NaN
# 34    Tuesday   12:00:00  13:00:00       NaN          NaN        NaN
# 35    Tuesday   13:00:00  14:00:00       NaN          NaN        NaN
# 36  Wednesday   16:30:00  17:30:00       NaN          NaN        NaN
# 37   Thursday   12:00:00  13:00:00       NaN          NaN        NaN
# 38    Tuesday   16:00:00  17:00:00       NaN          NaN        NaN
# 39    Tuesday   15:30:00  16:30:00       NaN          NaN        NaN
# 40     Friday   11:00:00  12:00:00       NaN          NaN        NaN
# 41     Monday   14:30:00  15:30:00       NaN          NaN        NaN
# 42  Wednesday   12:00:00  14:00:00       NaN          NaN        NaN
# 43   Thursday   13:00:00  14:00:00       NaN          NaN        NaN
# 44  Wednesday   16:00:00  17:00:00       NaN          NaN        NaN
# 45     Friday   14:00:00  15:00:00       NaN          NaN        NaN
# 46        NaN        NaN       NaN       NaN          NaN        NaN
# 47    Tuesday   15:30:00  16:30:00       NaN          NaN        NaN
# 48     Friday   11:00:00  12:30:00       NaN          NaN        NaN
# 49     Monday   13:00:00  14:00:00       NaN          NaN        NaN
# 50  Wednesday   15:00:00  16:00:00       NaN          NaN        NaN
# 51  Wednesday   15:00:00  17:00:00       NaN          NaN        NaN
# 52     Monday   15:00:00  16:00:00       NaN          NaN        NaN
# 53        NaN        NaN       NaN       NaN          NaN        NaN
# 54     Friday   11:45:00  12:45:00       NaN          NaN        NaN
# 55   Thursday   14:30:00  15:30:00       NaN          NaN        NaN
# 56     Monday   12:00:00  13:15:00       NaN          NaN        NaN
# 57    Tuesday   14:00:00  15:00:00       NaN          NaN        NaN
# 58  Wednesday   16:00:00  17:00:00       NaN          NaN        NaN
# 59   Thursday   14:00:00  15:00:00       NaN          NaN        NaN
# 60     Monday    9:00:00  10:00:00       NaN          NaN        NaN
#
#    Time_comments
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 6            NaN
# 7            NaN
# 8            NaN
# 9            NaN
# 10           NaN
# 11           NaN
# 12           NaN
# 13           NaN
# 14           NaN
# 15           NaN
# 16           NaN
# 17           NaN
# 18           NaN
# 19           NaN
# 20           NaN
# 21           NaN
# 22           NaN
# 23           NaN
# 24           NaN
# 25           NaN
# 26           NaN
# 27           NaN
# 28           NaN
# 29           NaN
# ..           ...
# 31           NaN
# 32           NaN
# 33           NaN
# 34           NaN
# 35      Biweekly
# 36           NaN
# 37           NaN
# 38           NaN
# 39           NaN
# 40           NaN
# 41           NaN
# 42           NaN
# 43           NaN
# 44           NaN
# 45           NaN
# 46           NaN
# 47           NaN
# 48           NaN
# 49           NaN
# 50           NaN
# 51           NaN
# 52      Biweekly
# 53           NaN
# 54           NaN
# 55      Biweekly
# 56      Biweekly
# 57           NaN
# 58           NaN
# 59           NaN
# 60           NaN
#
# [61 rows x 13 columns]

# %%
int(dt.datetime.strptime(mock_time(x['Day'],x['Time_start'], x['Timezone'])[:-3]+'00',
                                                    "%Y-%m-%dT%H:%M:%S%z").timestamp())
# Out:
# 1583510400
